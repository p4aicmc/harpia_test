# %%
import numpy as np
import pyspark # beacause pyspark >>>> pandas geopandas???
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, FloatType
import json
import time
import math
from math import sin, cos, sqrt, atan2, radians
import shapely.geometry

# %%
# Imports for the path planners

# AG
from libs.AG.genetic import Subject, Genetic
from libs.AG.model import Mapa, Conversor, CartesianPoint
from libs.AG.visualization import vis_mapa

# RRT
from libs.RRT.rrt import RRT

# PFP
from libs.PotentialFieldPlanning.potential_field_planning import potential_field_planning

# %%
from libs.RayCasting.raycasting import point_in_polygon, Vector

# %%
# from pyspark.sql import SparkSession
# spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()

# %%
# from os import walk

# filenames = next(walk('./data'), (None, None, []))[2]  # [] if no file

# %%
from collections import namedtuple
cartesiano = namedtuple('cart_tuple', ['x', 'y'])

# %% [markdown]
# ### READ MAPS

# %%
f = open('/home/vannini/harpia/json/mapa.json')
mapa = json.load(f)
f.close()

# %%
class waypoint:
    def __init__(self, lat, long):
        self.latitude = lat
        self.longitude = long

# %%
class cart:
    def __init__(self, x, y):
        self.x = x
        self.y = y

# %% [markdown]
# ### Aux functions

# %%
def distance(origin, destination):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(origin[1])
    lon1 = radians(origin[0])
    lat2 = radians(destination[1])
    lon2 = radians(destination[0])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    return R * c

# %%
def euclidean_distance(A, B):
    return math.sqrt((B.x - A.x) ** 2 + (B.y - A.y) ** 2)

# %%
def calc_dist_path(path):
    dist = 0
    i = 1
    for p in path:
        if p != path[-1]:
            A = CartesianPoint(p[0], p[1])
            B = CartesianPoint(path[i][0], path[i][1])
            dist += euclidean_distance(A, B)
            i += 1

    return dist

# %%
def pass_through_obstacle(obstacle_points, line_points):
#     poly = shapely.geometry.Polygon([[-9.5, -2], [2, 2], [3, 4], [-1, 3]])
#     line = shapely.geometry.LineString([[-10, -5], [15, 5]])
    poly = shapely.geometry.Polygon(obstacle_points)
    line = shapely.geometry.LineString(line_points)
    
    return line.intersects(poly)

# %%
def geo_to_cart(geo_point, geo_home):
        
        def calc_y(lat, lat_):
            return (lat - lat_) * (10000000.0 / 90)
        def calc_x(longi, longi_, lat_):
            return (longi - longi_) * (
                6400000.0 * (math.cos(lat_ * math.pi / 180) * 2 * math.pi / 360)
            )

        x = calc_x(geo_point[0], geo_home[0], geo_home[1])
        y = calc_y(geo_point[1], geo_home[1])

        return [x, y]

# %%
def cart_to_geo(cartesian_point, geo_home):
        def calc_latitude_y(lat_, y):
            return ((y * 90) / 10000000.0) + lat_

        def calc_longitude_x(lat_, longi_, x):
            return ((x * 90) / (10008000 * math.cos(lat_ * math.pi / 180))) + longi_

        longitude_x = calc_longitude_x(
            geo_home.latitude, geo_home.longitude, cartesian_point.x
        )
        latitude_y = calc_latitude_y(geo_home.latitude, cartesian_point.y)

        return GeoPoint(latitude_y, longitude_x, 10)

# %%
def list_geo_to_cart(l, geo_home):
        cart_list = []
        for i in l:
            cart_list = cart_list + [geo_to_cart(i, geo_home)]
        return cart_list

def list_cart_to_geo(l, geo_home):
        for i in l:
            yield cart_to_geo(i, geo_home)

# %%
def feasibility(route, obstacles, destination):
    """Checks if the route is feasible

    Args:
        route ([type]): [description]
        obstacles ([type]): [description]
        destination ([type]): [description]

    Returns:
        string: 'infeasible' - the route hits an obstacle
                'verify'     - the route does not arrive at the destination, according to min precision
                'feasible'   - the route is alright
    """

    # Minimum distance the last waypoint needs to be from the destination wp
    MIN_PRECISION = 10

    last_waypoint = Vector(route[-1][0], route[-1][1])
#     print(f"feasibility last_waypoint={last_waypoint}  destination={destination}")
    distance_to_objective = distance(last_waypoint, destination)
#     print(f"feasibility distance_to_objective={distance_to_objective}")

    for obstacle in obstacles:
        for (x, y) in route:
            waypoint = Vector(x, y)
            if point_in_polygon(waypoint, obstacle):
                return "infeasible", distance_to_objective

    if distance_to_objective > MIN_PRECISION:
        return "verify", distance_to_objective

    return "feasible", distance_to_objective

# %%
def feasibility_ag(fitness_trace):
    if fitness_trace[1] > 0:  # Hit obstacle (fit_obs) (max 1 hit)
        return "infeasible"
    elif fitness_trace[0] > 10:  # Away from destination wp (fit_d) (max 10 meters)
        return "verify"
    else:
        return "feasible"

# %%
def get_first_factible_route(ag):
    for subject in ag.history:
        feasibility_result = feasibility_ag(subject['fitness_trace'])

        if feasibility_result == "feasible":
            return subject['birth_time']

    return None

# %%
def rrt(from_wp1, to_wp1, map, geo_home1, obstacleList1,save_filename=None):
    
    from_wp = waypoint(from_wp1[1], from_wp1[0])
    to_wp = waypoint(to_wp1[1], to_wp1[0])
    geo_home = waypoint(geo_home1[1], geo_home1[0])

    obstacleList = [[cartesiano( x = p[0], y= p[1]) for p in obstacle] for obstacle in obstacleList1]
    
    origin = Conversor.geo_to_cart(from_wp, geo_home)

    destination = Conversor.geo_to_cart(to_wp, geo_home)

#     rc_map = Mapa(
#         origin,
#         destination,
# #         areas_n=obstacleList,
#     )

    # Define the rand_area, based on origin and destination coordinates
    ps = [origin.x, origin.y, destination.x, destination.y]
    
    rand_area_x = math.floor(min(ps) * 1.2)
    rand_area_y = math.ceil(max(ps) * 1.2)
    rand_area = [rand_area_x, rand_area_y]


    # Set Initial parameters
    rrt = RRT(
        start=[origin.x, origin.y],
        goal=[destination.x, destination.y],
        rand_area=rand_area,
        obstacle_list=obstacleList,
        expand_dis=25,  # minumum precision, to consider inside the goal (meters) 100
        path_resolution=1,
        goal_sample_rate=50,
        max_iter=5000,
        check_collision_mode="ray_casting",
    )

    start_time = time.time()
    route = rrt.planning(animation=False)

    if route is not None:
        route = list(reversed(route))

    time_taken = time.time() - start_time

    if route is None:
#         print("Cannot find route")
        return None
    else:
#         print("found route!!")
#         print(f"route={route}")

        feasibility_res, distance_to_objective = feasibility(
            route, obstacleList, destination
        )

        # Draw final route
        if save_filename:
            vis_mapa(rc_map, route=route, save=f"{save_filename}.png")

        return (
            route,
            calc_dist_path(route),
            feasibility_res,
            distance_to_objective,
            time_taken,
            len(route),
        )

# %%
def pfp(from_wp1, to_wp1, map, geo_home1, obstacleList1):
#     origin = Conversor.geo_to_cart(from_wp.geo, map.geo_home)
#     rospy.loginfo(f"origin={origin}")

#     destination = Conversor.geo_to_cart(to_wp.geo, map.geo_home)
#     rospy.loginfo(f"destination={destination}")

    from_wp = waypoint(from_wp1[1], from_wp1[0])
    to_wp = waypoint(to_wp1[1], to_wp1[0])
    geo_home = waypoint(geo_home1[1], geo_home1[0])
    
    origin = Conversor.geo_to_cart(from_wp, geo_home)

    destination = Conversor.geo_to_cart(to_wp, geo_home)    
    
    # ---
    # obstacleList for check_collision_mode='ray_casting'
#     obstacleList = [[Conversor.geo_to_cart(p.geo, map.geo_home) for p in area.points] for area in map.nfz]
    obstacleList = [[cartesiano( x = p[0], y= p[1]) for p in obstacle] for obstacle in obstacleList1]

    # Creates the ag_map in a structure the AG will understand
    rc_map = Mapa(
        origin,
        destination,
        areas_n=obstacleList,
    )
    # ---

    resolution = 20

    start_time = time.time()
    route = potential_field_planning(origin, destination, obstacleList, resolution)
    time_taken = time.time() - start_time

    if route is None:
        return None
    else:
        print("found route!!")

        feasibility_res, distance_to_objective = feasibility(route, obstacleList, destination)
        #to_waypointList(route, map.geo_home)
        return (
            route,
            calc_dist_path(route),
            feasibility_res,
            distance_to_objective,
            time_taken,
            len(route),
        )

# %%
def ag(from_wp1, to_wp1, map, geo_home1, obstacleList1):

    # Convert map to ag_map
    # nfzs has this structure:
    # nfzs = [
    #     [CartesianPoint(), CartesianPoint(), CartesianPoint(), CartesianPoint()],
    #     ...
    # ]
    
    from_wp = waypoint(from_wp1[1], from_wp1[0])
    to_wp = waypoint(to_wp1[1], to_wp1[0])
    geo_home = waypoint(geo_home1[1], geo_home1[0])
    
    origin = Conversor.geo_to_cart(from_wp, geo_home)

    destination = Conversor.geo_to_cart(to_wp, geo_home)    
    
    
    nfzs = [[cartesiano( x = p[0], y= p[1]) for p in obstacle] for obstacle in obstacleList1]
    
    # Creates the ag_map in a structure the AG will understand
    ag_map = Mapa(
        origin,
        destination,
        areas_n=nfzs,
        # inflation_rate gives a sense of security, expanding the limits of each obstacle.  Defaults to 0.1.
        inflation_rate=0.1,
    )

    ag = Genetic(
        Subject,
        ag_map,
        px0=ag_map.origin.x,  # CartesianPoint
        py0=ag_map.origin.y,  # CartesianPoint
        taxa_cross=5,
        population_size=20,
        max_exec_time=120,
        C_d=1000,
        C_obs=1000000,
        C_con=1,
        C_cur=10,
        C_t=10,
        C_dist=100,
        C_z_bonus=0,
        v_min=-3.0,
        v_max=3.0,
        e_min=-3,
        e_max=3,
        a_min=-3.0,
        a_max=3.0,
        T_min=5,
        T_max=15,
        delta_T=10,
        min_precision=10,
        mutation_prob=0.7,
        gps_imprecision=1,
    )

    best = ag.run(info=True)

    route = best.get_route()

    # Check if route is feasible
    feasibility_res = feasibility_ag(best.fitness_trace)

    distance_path = best.fitness_trace[5]  # (fit_dist)
    distance_to_objective = best.fitness_trace[0]  # (fit_d)

    first_factible_route_found_time = get_first_factible_route(ag)


    return (
        route,
        distance_path,
        feasibility_res,
        distance_to_objective,
        first_factible_route_found_time,
        len(route),
    )

# %% [markdown]
# ## main loop

# %%
import pandas as pd
data = pd.read_csv("GFG")
teste = data[["origin", "destination"]].drop_duplicates()

# making copy of team column
new = data["destination"].copy()
 
# concatenating team with name column
# overwriting name column
teste["testes"]= data["origin"].str.cat(new, sep ="_")
 
# display
col_list = teste['testes'].to_numpy()
col_list
# Out:
# array(['region_1_region_2', 'region_1_region_3', 'region_1_region_4',
#        'region_1_region_5', 'region_1_region_6', 'region_1_region_7',
#        'region_1_region_8', 'region_1_region_9', 'region_1_region_10',
#        'region_1_region_11', 'region_1_region_12', 'region_1_base_1',
#        'region_1_base_2', 'region_1_base_3', 'region_1_base_4',
#        'region_2_region_1', 'region_2_region_3', 'region_2_region_4',
#        'region_2_region_5', 'region_2_region_6', 'region_2_region_7',
#        'region_2_region_8', 'region_2_region_9', 'region_2_region_10',
#        'region_2_region_11', 'region_2_region_12', 'region_2_base_1',
#        'region_2_base_2', 'region_2_base_3', 'region_2_base_4',
#        'region_3_region_1', 'region_3_region_2', 'region_3_region_4',
#        'region_3_region_5', 'region_3_region_6', 'region_3_region_7',
#        'region_3_region_8', 'region_3_region_9', 'region_3_region_10',
#        'region_3_region_11', 'region_3_region_12', 'region_3_base_1',
#        'region_3_base_2', 'region_3_base_3', 'region_3_base_4',
#        'region_4_region_1', 'region_4_region_2', 'region_4_region_3',
#        'region_4_region_5', 'region_4_region_6', 'region_4_region_7',
#        'region_4_region_8', 'region_4_region_9', 'region_4_region_10',
#        'region_4_region_11', 'region_4_region_12', 'region_4_base_1',
#        'region_4_base_2', 'region_4_base_3', 'region_4_base_4',
#        'region_5_region_1', 'region_5_region_2', 'region_5_region_3',
#        'region_5_region_4', 'region_5_region_6', 'region_5_region_7',
#        'region_5_region_8', 'region_5_region_9', 'region_5_region_10',
#        'region_5_region_11', 'region_5_region_12', 'region_5_base_1',
#        'region_5_base_2', 'region_5_base_3', 'region_5_base_4',
#        'region_6_region_1', 'region_6_region_2', 'region_6_region_3',
#        'region_6_region_4', 'region_6_region_5', 'region_6_region_7',
#        'region_6_region_8', 'region_6_region_9', 'region_6_region_10',
#        'region_6_region_11', 'region_6_region_12', 'region_6_base_1',
#        'region_6_base_2', 'region_6_base_3', 'region_6_base_4',
#        'region_7_region_1', 'region_7_region_2', 'region_7_region_3',
#        'region_7_region_4', 'region_7_region_5', 'region_7_region_6',
#        'region_7_region_8', 'region_7_region_9', 'region_7_region_10',
#        'region_7_region_11', 'region_7_region_12', 'region_7_base_1',
#        'region_7_base_2', 'region_7_base_3', 'region_7_base_4',
#        'region_8_region_1', 'region_8_region_2', 'region_8_region_3',
#        'region_8_region_4', 'region_8_region_5', 'region_8_region_6',
#        'region_8_region_7', 'region_8_region_9', 'region_8_region_10',
#        'region_8_region_11', 'region_8_region_12', 'region_8_base_1',
#        'region_8_base_2', 'region_8_base_3', 'region_8_base_4',
#        'region_9_region_1', 'region_9_region_2', 'region_9_region_3',
#        'region_9_region_4', 'region_9_region_5', 'region_9_region_6',
#        'region_9_region_7', 'region_9_region_8', 'region_9_region_10',
#        'region_9_region_11', 'region_9_region_12', 'region_9_base_1',
#        'region_9_base_2', 'region_9_base_3', 'region_9_base_4',
#        'region_10_region_1', 'region_10_region_2', 'region_10_region_3',
#        'region_10_region_4', 'region_10_region_5', 'region_10_region_6',
#        'region_10_region_7', 'region_10_region_8', 'region_10_region_9',
#        'region_10_region_11', 'region_10_region_12', 'region_10_base_1',
#        'region_10_base_2', 'region_10_base_3', 'region_10_base_4',
#        'region_11_region_1', 'region_11_region_2', 'region_11_region_3',
#        'region_11_region_4', 'region_11_region_5', 'region_11_region_6',
#        'region_11_region_7', 'region_11_region_8', 'region_11_region_9',
#        'region_11_region_10', 'region_11_region_12', 'region_11_base_1',
#        'region_11_base_2', 'region_11_base_3', 'region_11_base_4'],
#       dtype=object)

# %%
log = []

# %%
log_id = 0
file_id = 0
for m in mapa:
    print(m['id'])
    geo_home = m['geo_home']
    # getting list of oringin points - conners + centers of all regions (roi + bases) and
    # destination points - centers of all regions (roi + bases)
    origin_points = list()
    origin_names = list()
    destination_points = list()
    destination_names = list()
    for region in  m['roi']+m['bases']:
        origin_points =  origin_points + region['geo_points'] 
        #+ [region['center']]
        origin_names = origin_names + [region['name']]
#         destination_points =  destination_points + [region['center']]
#         destination_names = destination_names + [region['name']]
    destination_points =  origin_points
    destination_names = origin_names
    if(m['id']!=0):
        i=0 
        for o_name, origin in zip(origin_names, origin_points):
            for d_name, destination in zip(destination_names, destination_points):
                a = o_name+"_"+d_name
                if(not(a in col_list)):
                    break
                if(o_name!= d_name):  
                    print(o_name+"->"+d_name)

                    # distance in straight line
                    d_sl = distance(origin, destination)

                    # calc number of obstacles that the path in straight line from origin to destination crosses
                    obst_qty = 0
                    line = list_geo_to_cart([origin[:-1]] + [destination[:-1]], geo_home)

                    obstacleList = []
                    obstacleList1 = []
                    # fazer funcao no n'o ros que conte qtd de obstaculos 
                    for nfz in m['nfz']:
                        poly = list_geo_to_cart(nfz['geo_points'], geo_home)
                        poly1 = Conversor.list_geo_to_cart(nfz['geo_points'], geo_home)
                        obstacleList += [poly]
                        obstacleList1 += [poly1]
                        if(pass_through_obstacle(poly, line)):
                            obst_qty += 1


                    ##RRT
                    (rota, d_path, factibility, d_destination, time_alg, qty_wp) = rrt(origin, destination, m, geo_home, obstacleList)
                    ## save line: ++id, origin, destination, "rrt", d_sl, obst_qty, time_alg, d_path, ratio, d_destination
                    ##, factibility, qty_wp, first_factible_route_found_time, exception
                    ratio = d_path/d_sl
                    first_factible_route_found_time = ""
                    exception = ""

                    log.append([i, o_name, d_name, "rrt", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 100])         
                    log.append([i, o_name, d_name, "rrt", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 75])
                    log.append([i, o_name, d_name, "rrt", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 50])
                    log.append([i, o_name, d_name, "rrt", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 25])
                    log.append([i, o_name, d_name, "rrt", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 15])
                    log.append([i, o_name, d_name, "rrt", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 10])
                    i = i+1

                    ##pfp
                    (rota, d_path, factibility, d_destination, time_alg, qty_wp) = pfp(origin, destination, m, geo_home, obstacleList)
                    ## save line: ++id, origin, destination, "rrt", d_sl, obst_qty, time_alg, d_path, ratio, d_destination
                    ##, factibility, qty_wp, first_factible_route_found_time, exception
                    ratio = d_path/d_sl
                    first_factible_route_found_time = ""
                    exception = ""

                    log.append([i, o_name, d_name, "pfp", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 100])         
                    log.append([i, o_name, d_name, "pfp", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 75])
                    log.append([i, o_name, d_name, "pfp", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 50])
                    log.append([i, o_name, d_name, "pfp", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 25])
                    log.append([i, o_name, d_name, "pfp", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 15])
                    log.append([i, o_name, d_name, "pfp", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 10])
                    i = i +1

                    ##ag
                    (rota, d_path, factibility, d_destination, time_alg, qty_wp) = ag(origin, destination, m, geo_home, obstacleList)
                    ## save line: ++id, origin, destination, "rrt", d_sl, obst_qty, time_alg, d_path, ratio, d_destination
                    ##, factibility, qty_wp, first_factible_route_found_time, exception
                    ratio = d_path/d_sl
                    first_factible_route_found_time = ""
                    exception = ""
                    log.append([i, o_name, d_name, "ag", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 100])         
                    log.append([i, o_name, d_name, "ag", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 75])
                    log.append([i, o_name, d_name, "ag", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 50])
                    log.append([i, o_name, d_name, "ag", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 25])
                    log.append([i, o_name, d_name, "ag", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 15])
                    log.append([i, o_name, d_name, "ag", d_sl, obst_qty, time_alg, d_path, ratio,d_destination, 
                                factibility, qty_wp,first_factible_route_found_time, exception, 10])
                    i = i + 1

            # stops to test 
#                 if(i > 1): 
#                     break
#             if(i > 1): 
#                 break
# Out:
# 0
# 1
# region_2->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 17039.473836025063
# Meteor! Reseting routes
# 17039.473836025063
# Meteor! Reseting routes
# 17039.473836025063
# Meteor! Reseting routes
# 17038.296740333135
# Meteor! Reseting routes
# 17038.296740333135
# Meteor! Reseting routes
# 17038.296740333135
# Meteor! Reseting routes
# 17038.296740333135
# Meteor! Reseting routes
# 17038.296740333135
# Meteor! Reseting routes
# 16994.539181362215
# Meteor! Reseting routes
# 16994.539181362215
# Meteor! Reseting routes
# 16959.932204303073
# Meteor! Reseting routes
# 16901.483051535964
# Meteor! Reseting routes
# 16901.483051535964
# Meteor! Reseting routes
# 16894.154780567012
# Meteor! Reseting routes
# 16894.154780567012
# Meteor! Reseting routes
# 16894.154780567012
# Meteor! Reseting routes
# 16893.871456895547
# Meteor! Reseting routes
# 16890.48386510018
# Meteor! Reseting routes
# 16890.48386510018
# AG ended
# region_3->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 67710.50664384106
# Meteor! Reseting routes
# 65701.28161477388
# Meteor! Reseting routes
# 39794.070918919024
# Meteor! Reseting routes
# 38850.755161471774
# Meteor! Reseting routes
# 38789.7603802693
# Meteor! Reseting routes
# 38789.7603802693
# Meteor! Reseting routes
# 38789.7603802693
# Meteor! Reseting routes
# 38456.465630451174
# Meteor! Reseting routes
# 38388.68005830624
# Meteor! Reseting routes
# 37703.92779233867
# Meteor! Reseting routes
# 37703.92779233867
# Meteor! Reseting routes
# 37703.92779233867
# Meteor! Reseting routes
# 36296.59215753338
# Meteor! Reseting routes
# 36148.934038333995
# Meteor! Reseting routes
# 36148.934038333995
# Meteor! Reseting routes
# 36148.2052068112
# AG ended
# region_3->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 38593.657451262006
# Meteor! Reseting routes
# 37198.97263222336
# Meteor! Reseting routes
# 37112.22999691796
# Meteor! Reseting routes
# 37112.22952033046
# Meteor! Reseting routes
# 36820.828402267856
# Meteor! Reseting routes
# 36820.04354724877
# Meteor! Reseting routes
# 36820.04354724877
# Meteor! Reseting routes
# 36820.04343093933
# Meteor! Reseting routes
# 36820.04201489518
# Meteor! Reseting routes
# 36782.53229783199
# Meteor! Reseting routes
# 36782.53229783199
# Meteor! Reseting routes
# 36782.45391515304
# AG ended
# region_4->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 45692.449890499876
# Meteor! Reseting routes
# 45691.02926101504
# Meteor! Reseting routes
# 45691.02926101504
# Meteor! Reseting routes
# 45691.02926101504
# Meteor! Reseting routes
# 45660.61361116494
# Meteor! Reseting routes
# 45660.61361116494
# Meteor! Reseting routes
# 45146.99260540567
# Meteor! Reseting routes
# 45138.72576489671
# Meteor! Reseting routes
# 45138.72576489671
# Meteor! Reseting routes
# 45138.72576489671
# Meteor! Reseting routes
# 45110.56293017423
# Meteor! Reseting routes
# 45110.56293017423
# Meteor! Reseting routes
# 45110.56293017423
# Meteor! Reseting routes
# 45110.56293017423
# Meteor! Reseting routes
# 45110.56293017423
# Meteor! Reseting routes
# 45098.618599078734
# AG ended
# region_4->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 69541.83618769543
# Meteor! Reseting routes
# 67823.70815119911
# Meteor! Reseting routes
# 67823.70815119911
# Meteor! Reseting routes
# 67823.70815119911
# Meteor! Reseting routes
# 65885.94429219597
# Meteor! Reseting routes
# 56254.415383232554
# Meteor! Reseting routes
# 56254.415383232554
# Meteor! Reseting routes
# 56185.043750852354
# Meteor! Reseting routes
# 52309.00883906564
# Meteor! Reseting routes
# 51063.201969575435
# Meteor! Reseting routes
# 51053.03205971746
# Meteor! Reseting routes
# 48758.79513842735
# AG ended
# region_4->region_3
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 44823.30650161419
# Meteor! Reseting routes
# 34973.27614101362
# Meteor! Reseting routes
# 34973.27614101362
# Meteor! Reseting routes
# 34924.26913197034
# Meteor! Reseting routes
# 34924.26913197034
# Meteor! Reseting routes
# 34924.26913197034
# Meteor! Reseting routes
# 34924.26913197034
# Meteor! Reseting routes
# 34924.26913197034
# Meteor! Reseting routes
# 34849.4203796384
# Meteor! Reseting routes
# 34849.4203796384
# Meteor! Reseting routes
# 34849.4203796384
# Meteor! Reseting routes
# 34849.4203796384
# Meteor! Reseting routes
# 34849.4203796384
# Meteor! Reseting routes
# 34849.4203796384
# Meteor! Reseting routes
# 34848.95258692214
# Meteor! Reseting routes
# 34848.95258692214
# Meteor! Reseting routes
# 34848.95258692214
# Meteor! Reseting routes
# 34848.95258692214
# Meteor! Reseting routes
# 34840.15534259676
# Meteor! Reseting routes
# 34825.76648587471
# Meteor! Reseting routes
# 34825.76648587471
# AG ended
# region_5->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 98040.57774782859
# Meteor! Reseting routes
# 98040.57774782859
# Meteor! Reseting routes
# 88182.39977716352
# Meteor! Reseting routes
# 88182.39977716352
# Meteor! Reseting routes
# 80893.11677468929
# Meteor! Reseting routes
# 80835.55169228725
# Meteor! Reseting routes
# 80835.55169228725
# Meteor! Reseting routes
# 58012.85588143751
# Meteor! Reseting routes
# 58012.85588143751
# Meteor! Reseting routes
# 58012.85588143751
# Meteor! Reseting routes
# 45649.38621930898
# Meteor! Reseting routes
# 45649.38621930898
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45421.857784494176
# Meteor! Reseting routes
# 45215.42103509206
# Meteor! Reseting routes
# 45193.39226379377
# Meteor! Reseting routes
# 45193.39226379377
# Meteor! Reseting routes
# 45193.39226379377
# Meteor! Reseting routes
# 45193.39226379377
# Meteor! Reseting routes
# 45193.39226379377
# AG ended
# region_5->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 102953.9007389996
# Meteor! Reseting routes
# 85477.91694963431
# Meteor! Reseting routes
# 85477.91694963431
# Meteor! Reseting routes
# 85477.91694963431
# Meteor! Reseting routes
# 85477.91694963431
# Meteor! Reseting routes
# 85477.91694963431
# Meteor! Reseting routes
# 85477.91694963431
# Meteor! Reseting routes
# 85477.5504037875
# Meteor! Reseting routes
# 85477.5504037875
# Meteor! Reseting routes
# 53514.64754135511
# Meteor! Reseting routes
# 53514.64754135511
# Meteor! Reseting routes
# 53336.78555338357
# Meteor! Reseting routes
# 53064.86586196133
# Meteor! Reseting routes
# 53064.86586196133
# Meteor! Reseting routes
# 53064.86586196133
# Meteor! Reseting routes
# 53064.86586196133
# Meteor! Reseting routes
# 53064.86586196133
# Meteor! Reseting routes
# 53064.86586196133
# Meteor! Reseting routes
# 52975.44099914185
# AG ended
# region_5->region_3
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 26276.300997583254
# Meteor! Reseting routes
# 26276.300997583254
# Meteor! Reseting routes
# 26276.300997583254
# Meteor! Reseting routes
# 26276.300997583254
# Meteor! Reseting routes
# 26276.300997583254
# Meteor! Reseting routes
# 26276.300997579427
# Meteor! Reseting routes
# 26276.300997579427
# Meteor! Reseting routes
# 26276.300997579427
# Meteor! Reseting routes
# 26275.04167197255
# Meteor! Reseting routes
# 26275.04167197255
# Meteor! Reseting routes
# 26275.04167197255
# Meteor! Reseting routes
# 26275.04167197255
# Meteor! Reseting routes
# 26275.04167197255
# Meteor! Reseting routes
# 26275.041671255807
# Meteor! Reseting routes
# 26275.041671255807
# Meteor! Reseting routes
# 26275.041671255807
# Meteor! Reseting routes
# 26275.041671255807
# Meteor! Reseting routes
# 26275.041671255807
# Meteor! Reseting routes
# 26275.04166990015
# Meteor! Reseting routes
# 26275.04166990015
# Meteor! Reseting routes
# 26275.04166990015
# Meteor! Reseting routes
# 26275.04166990015
# Meteor! Reseting routes
# 26275.041669866958
# Meteor! Reseting routes
# 26275.041669866958
# Meteor! Reseting routes
# 26275.041669866958
# Meteor! Reseting routes
# 26275.041669866958
# Meteor! Reseting routes
# 26275.041669866958
# Meteor! Reseting routes
# 26275.041669866958
# Meteor! Reseting routes
# 26275.041669866958
# Meteor! Reseting routes
# 26274.998384071554
# Meteor! Reseting routes
# 26274.998384071554
# Meteor! Reseting routes
# 26274.998384071554
# Meteor! Reseting routes
# 26274.998384071554
# Meteor! Reseting routes
# 26274.998384071554
# AG ended
# region_5->region_4
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 8388.689409477209
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5619.516234737282
# Meteor! Reseting routes
# 5618.937793257733
# Meteor! Reseting routes
# 5618.937793257733
# Meteor! Reseting routes
# 5618.937793257733
# Meteor! Reseting routes
# 5618.937793257733
# Meteor! Reseting routes
# 5618.937793257733
# Meteor! Reseting routes
# 5618.937793257733
# Meteor! Reseting routes
# 5618.937793257733
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5618.621129035335
# Meteor! Reseting routes
# 5617.131420841196
# Meteor! Reseting routes
# 5617.131420841196
# Meteor! Reseting routes
# 5617.131420841196
# Meteor! Reseting routes
# 5617.131420841196
# AG ended
# region_6->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 58146.95553010588
# Meteor! Reseting routes
# 43912.81183712048
# Meteor! Reseting routes
# 43912.81183712048
# Meteor! Reseting routes
# 43912.81183712048
# Meteor! Reseting routes
# 43912.81183712048
# Meteor! Reseting routes
# 43912.81183712048
# Meteor! Reseting routes
# 43514.45066147968
# Meteor! Reseting routes
# 41554.42282238523
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40674.63113198656
# Meteor! Reseting routes
# 40633.38395345847
# Meteor! Reseting routes
# 40633.38395345847
# Meteor! Reseting routes
# 40633.38395345847
# Meteor! Reseting routes
# 40633.38395345847
# Meteor! Reseting routes
# 40633.38395345847
# AG ended
# region_6->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 129338.34210298871
# Meteor! Reseting routes
# 42275.269217123605
# Meteor! Reseting routes
# 39345.820983304926
# Meteor! Reseting routes
# 39345.820983304926
# Meteor! Reseting routes
# 39345.820983304926
# Meteor! Reseting routes
# 37478.91063157058
# Meteor! Reseting routes
# 37478.91063157058
# Meteor! Reseting routes
# 37478.91063157058
# Meteor! Reseting routes
# 37464.11718110704
# Meteor! Reseting routes
# 37193.191589395305
# Meteor! Reseting routes
# 37193.191589395305
# Meteor! Reseting routes
# 37193.191589395305
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37190.72649850799
# Meteor! Reseting routes
# 37181.89414862055
# Meteor! Reseting routes
# 37181.89414862055
# Meteor! Reseting routes
# 37181.89414862055
# Meteor! Reseting routes
# 37181.89414862055
# Meteor! Reseting routes
# 37181.89414862055
# AG ended
# region_6->region_3
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 4358.471147796853
# Meteor! Reseting routes
# 4122.678266262545
# Meteor! Reseting routes
# 4122.678266262545
# Meteor! Reseting routes
# 4117.303643340239
# Meteor! Reseting routes
# 4117.303643340239
# Meteor! Reseting routes
# 4117.303643340239
# Meteor! Reseting routes
# 4058.6999249789724
# Meteor! Reseting routes
# 4058.6999249789724
# Meteor! Reseting routes
# 4051.656681282354
# Meteor! Reseting routes
# 4049.830336682123
# Meteor! Reseting routes
# 4046.628976860404
# AG ended
# region_6->region_4
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 43679.7174573782
# Meteor! Reseting routes
# 43679.7174573782
# Meteor! Reseting routes
# 43002.24994221731
# Meteor! Reseting routes
# 36862.16072236906
# Meteor! Reseting routes
# 36417.38277162832
# Meteor! Reseting routes
# 36106.36354878941
# Meteor! Reseting routes
# 36059.110564570256
# Meteor! Reseting routes
# 36059.110564570256
# Meteor! Reseting routes
# 36059.110564570256
# Meteor! Reseting routes
# 36059.110564570256
# Meteor! Reseting routes
# 36059.053482901974
# Meteor! Reseting routes
# 36059.053482901974
# Meteor! Reseting routes
# 35960.65844607178
# Meteor! Reseting routes
# 35934.36737978886
# Meteor! Reseting routes
# 35934.36737978886
# AG ended
# region_6->region_5
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 31473.6181476808
# Meteor! Reseting routes
# 30787.37446533037
# Meteor! Reseting routes
# 30133.362634466106
# Meteor! Reseting routes
# 30133.362634466106
# Meteor! Reseting routes
# 30133.362634466106
# Meteor! Reseting routes
# 30133.362634466106
# Meteor! Reseting routes
# 30133.362634466106
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.20835057919
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# Meteor! Reseting routes
# 29576.14456288565
# AG ended
# 2
# region_2->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 17196.136470885063
# Meteor! Reseting routes
# 11343.910653051611
# Meteor! Reseting routes
# 11343.910653051611
# Meteor! Reseting routes
# 11268.064894578742
# Meteor! Reseting routes
# 11265.987529349062
# Meteor! Reseting routes
# 11265.987529349062
# Meteor! Reseting routes
# 11263.444265171087
# Meteor! Reseting routes
# 11263.444265171087
# Meteor! Reseting routes
# 11263.444265171087
# Meteor! Reseting routes
# 11263.444265171087
# Meteor! Reseting routes
# 11261.304601112619
# Meteor! Reseting routes
# 11261.304601112619
# Meteor! Reseting routes
# 11261.304601112619
# Meteor! Reseting routes
# 11261.304601112619
# Meteor! Reseting routes
# 10979.714492290668
# Meteor! Reseting routes
# 10647.358244027208
# AG ended
# region_3->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 19398.7108097225
# Meteor! Reseting routes
# 18734.539180315955
# Meteor! Reseting routes
# 18734.539180315955
# Meteor! Reseting routes
# 18734.539180315955
# Meteor! Reseting routes
# 18734.539180315955
# Meteor! Reseting routes
# 16090.306675047177
# Meteor! Reseting routes
# 16090.306675047177
# Meteor! Reseting routes
# 15626.139787735085
# Meteor! Reseting routes
# 15240.562373588231
# Meteor! Reseting routes
# 15240.562373588231
# Meteor! Reseting routes
# 15240.562373588231
# Meteor! Reseting routes
# 15176.353501429207
# Meteor! Reseting routes
# 15176.353501429207
# Meteor! Reseting routes
# 15176.353501429207
# Meteor! Reseting routes
# 15175.944665673689
# Meteor! Reseting routes
# 15079.163644976785
# AG ended
# region_3->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 8918.401671329659
# Meteor! Reseting routes
# 8218.182553512825
# Meteor! Reseting routes
# 8120.334946719002
# Meteor! Reseting routes
# 8120.334946719002
# Meteor! Reseting routes
# 7826.483816571279
# Meteor! Reseting routes
# 7726.915063479765
# Meteor! Reseting routes
# 7726.915063479765
# Meteor! Reseting routes
# 7726.915063479765
# Meteor! Reseting routes
# 7726.915063479765
# Meteor! Reseting routes
# 7726.915063479765
# Meteor! Reseting routes
# 7725.685341890766
# Meteor! Reseting routes
# 7725.685341890766
# Meteor! Reseting routes
# 7725.685341890766
# Meteor! Reseting routes
# 7725.685341890766
# Meteor! Reseting routes
# 7725.685341890766
# Meteor! Reseting routes
# 7721.96684848191
# AG ended
# region_4->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 12016.517220215608
# Meteor! Reseting routes
# 11041.69770837976
# Meteor! Reseting routes
# 10377.595675625293
# Meteor! Reseting routes
# 10141.47414264137
# Meteor! Reseting routes
# 10129.801957773516
# Meteor! Reseting routes
# 10111.645927692234
# Meteor! Reseting routes
# 10111.645927692234
# Meteor! Reseting routes
# 10111.645927692234
# Meteor! Reseting routes
# 10111.645927692234
# Meteor! Reseting routes
# 9633.153038647106
# Meteor! Reseting routes
# 9633.153038647106
# Meteor! Reseting routes
# 9633.153038647106
# Meteor! Reseting routes
# 9631.858420115377
# Meteor! Reseting routes
# 9631.858420115377
# AG ended
# region_4->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 44246.656439588
# Meteor! Reseting routes
# 23203.76945946401
# Meteor! Reseting routes
# 16931.456302671617
# Meteor! Reseting routes
# 16931.456302671617
# Meteor! Reseting routes
# 16368.698816631635
# Meteor! Reseting routes
# 16368.698816631635
# Meteor! Reseting routes
# 16368.698816631635
# Meteor! Reseting routes
# 16359.45078732021
# Meteor! Reseting routes
# 16359.45078732021
# Meteor! Reseting routes
# 16359.45078732021
# Meteor! Reseting routes
# 16359.45078732021
# Meteor! Reseting routes
# 16359.45078732021
# Meteor! Reseting routes
# 16359.45078732021
# Meteor! Reseting routes
# 16358.769772014119
# Meteor! Reseting routes
# 16358.769772014119
# Meteor! Reseting routes
# 16358.769772014119
# Meteor! Reseting routes
# 16321.316324177758
# Meteor! Reseting routes
# 15943.786689324845
# Meteor! Reseting routes
# 15943.786689324845
# Meteor! Reseting routes
# 15943.786689324845
# Meteor! Reseting routes
# 15943.786689324845
# Meteor! Reseting routes
# 15505.001492764242
# Meteor! Reseting routes
# 15505.001492764242
# Meteor! Reseting routes
# 14721.849084246865
# AG ended
# region_4->region_3
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 11587.87541552593
# Meteor! Reseting routes
# 11576.99455722955
# Meteor! Reseting routes
# 11576.99455722955
# Meteor! Reseting routes
# 11576.99455722955
# Meteor! Reseting routes
# 11576.99455722955
# Meteor! Reseting routes
# 11576.99455722955
# Meteor! Reseting routes
# 11576.99455722955
# Meteor! Reseting routes
# 11248.404113532522
# Meteor! Reseting routes
# 11248.404113532522
# Meteor! Reseting routes
# 10963.91593037865
# Meteor! Reseting routes
# 10963.91593037865
# Meteor! Reseting routes
# 10963.91593037865
# Meteor! Reseting routes
# 10963.91593037865
# Meteor! Reseting routes
# 10727.279797940448
# AG ended
# region_5->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 17541.557371077884
# Meteor! Reseting routes
# 17526.595276753593
# Meteor! Reseting routes
# 17526.595276753593
# Meteor! Reseting routes
# 17111.737347919858
# Meteor! Reseting routes
# 14532.124310259793
# Meteor! Reseting routes
# 14532.124310259793
# Meteor! Reseting routes
# 14532.124310259793
# Meteor! Reseting routes
# 14532.124310259793
# Meteor! Reseting routes
# 14532.043701746301
# Meteor! Reseting routes
# 14532.043701746301
# Meteor! Reseting routes
# 14532.043701746301
# Meteor! Reseting routes
# 14532.043701746301
# Meteor! Reseting routes
# 14532.043701746301
# Meteor! Reseting routes
# 14532.043701746301
# AG ended
# region_5->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 18616.096308178854
# Meteor! Reseting routes
# 18614.44930017324
# Meteor! Reseting routes
# 18614.44930017324
# Meteor! Reseting routes
# 10512.305643406198
# Meteor! Reseting routes
# 10512.305643406198
# Meteor! Reseting routes
# 10212.478047152417
# Meteor! Reseting routes
# 10212.478047152417
# Meteor! Reseting routes
# 10212.478047152417
# Meteor! Reseting routes
# 10212.478047152417
# Meteor! Reseting routes
# 10212.478047152417
# Meteor! Reseting routes
# 8079.974160614376
# Meteor! Reseting routes
# 7341.662250175456
# Meteor! Reseting routes
# 7309.30470019292
# Meteor! Reseting routes
# 7179.994023272606
# Meteor! Reseting routes
# 7166.258930629851
# AG ended
# region_5->region_3
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 21549.931626228794
# Meteor! Reseting routes
# 1774.4458692470093
# Meteor! Reseting routes
# 1774.4458692470093
# Meteor! Reseting routes
# 1763.040456507672
# Meteor! Reseting routes
# 1763.040456507672
# Meteor! Reseting routes
# 1763.040456507672
# Meteor! Reseting routes
# 1763.040456507672
# Meteor! Reseting routes
# 1762.918519207459
# Meteor! Reseting routes
# 1753.5732701700676
# Meteor! Reseting routes
# 1748.3290892989262
# Meteor! Reseting routes
# 1748.0193323742865
# Meteor! Reseting routes
# 1748.0193323742865
# Meteor! Reseting routes
# 1748.0193323742865
# Meteor! Reseting routes
# 1708.396801678562
# AG ended
# region_5->region_4
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 43505.019866500974
# Meteor! Reseting routes
# 18258.83266334027
# Meteor! Reseting routes
# 17163.80778749885
# Meteor! Reseting routes
# 17160.182778584607
# Meteor! Reseting routes
# 17160.182778584607
# Meteor! Reseting routes
# 17160.182778584607
# Meteor! Reseting routes
# 17160.182778584607
# Meteor! Reseting routes
# 17160.182778584607
# Meteor! Reseting routes
# 17160.182778584607
# Meteor! Reseting routes
# 17160.182778584607
# Meteor! Reseting routes
# 15023.771242315719
# Meteor! Reseting routes
# 12923.594634103978
# Meteor! Reseting routes
# 12923.594634103978
# Meteor! Reseting routes
# 12923.594634103978
# Meteor! Reseting routes
# 12923.586885207105
# Meteor! Reseting routes
# 12923.586885207105
# Meteor! Reseting routes
# 12923.586885207105
# Meteor! Reseting routes
# 12923.586885207105
# Meteor! Reseting routes
# 12917.49484144216
# Meteor! Reseting routes
# 12917.49484144216
# Meteor! Reseting routes
# 12917.49484144216
# Meteor! Reseting routes
# 12875.113344340467
# AG ended
# region_6->region_1
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 24758.975717396515
# Meteor! Reseting routes
# 24758.975717396515
# Meteor! Reseting routes
# 24758.975717396515
# Meteor! Reseting routes
# 24754.397709679717
# Meteor! Reseting routes
# 23871.52402740151
# Meteor! Reseting routes
# 22417.985141250454
# Meteor! Reseting routes
# 22417.985141250454
# Meteor! Reseting routes
# 22417.985141250454
# Meteor! Reseting routes
# 22417.985141250454
# Meteor! Reseting routes
# 22415.329298951714
# Meteor! Reseting routes
# 22415.329298951714
# AG ended
# region_6->region_2
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 23555.77230354949
# Meteor! Reseting routes
# 21230.49067474682
# Meteor! Reseting routes
# 21230.49067474682
# Meteor! Reseting routes
# 19532.5170932638
# Meteor! Reseting routes
# 19532.5170932638
# Meteor! Reseting routes
# 19532.5170932638
# Meteor! Reseting routes
# 19532.5170932638
# Meteor! Reseting routes
# 17110.880700437105
# Meteor! Reseting routes
# 17110.880700437105
# Meteor! Reseting routes
# 17110.880700437105
# Meteor! Reseting routes
# 17110.880700437105
# Meteor! Reseting routes
# 17110.880700437105
# Meteor! Reseting routes
# 17110.880700437105
# Meteor! Reseting routes
# 17108.665253313215
# AG ended
# region_6->region_3
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 10286.156199208597
# Meteor! Reseting routes
# 9649.928907631473
# Meteor! Reseting routes
# 9649.928907631473
# Meteor! Reseting routes
# 9649.928907631473
# Meteor! Reseting routes
# 9649.928907631473
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9222.99507785519
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# Meteor! Reseting routes
# 9218.535411566301
# AG ended
# region_6->region_4
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 39988.36520375005
# Meteor! Reseting routes
# 29268.922891264785
# Meteor! Reseting routes
# 29268.922891264785
# Meteor! Reseting routes
# 29256.238512622247
# Meteor! Reseting routes
# 29256.238512622247
# Meteor! Reseting routes
# 29256.238512622247
# Meteor! Reseting routes
# 27117.628326437585
# Meteor! Reseting routes
# 27114.7044337058
# Meteor! Reseting routes
# 27114.7044337058
# Meteor! Reseting routes
# 27114.7044337058
# Meteor! Reseting routes
# 27114.7044337058
# Meteor! Reseting routes
# 27114.7044337058
# Meteor! Reseting routes
# 27114.7044337058
# Meteor! Reseting routes
# 27114.7044337058
# Meteor! Reseting routes
# 26730.96408682485
# AG ended
# region_6->region_5
# Initiated RRT
# Finished initiating RRT
# Started RRT planning
# Starting Potential Field Planning
#     Generated potential field
# found route!!
# AG started
# Meteor! Reseting routes
# 9535.64124507789
# Meteor! Reseting routes
# 9535.64124507789
# Meteor! Reseting routes
# 9535.304940718228
# Meteor! Reseting routes
# 9535.304940718228
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9517.806713023989
# Meteor! Reseting routes
# 9512.289540754127
# Meteor! Reseting routes
# 9512.289540754127
# Meteor! Reseting routes
# 9512.289540754127
# Meteor! Reseting routes
# 9288.11743940663
# Meteor! Reseting routes
# 9288.11743940663
# Meteor! Reseting routes
# 9288.11743940663
# Meteor! Reseting routes
# 9287.696880097275
# Meteor! Reseting routes
# 9287.696880097275
# AG ended

# %%
import csv
  
fields = ['id', 'origin', 'destination', 'algorithm', 'distance_straight_line', 'obst_qty', 'time_to_plan', 'd_path', 
          'ratio', 'distance_to_objective', 'factibility', 'qty_wp', 'first_factible_route_found_time', 'exception',
          'battery'] 
    
# data rows of csv file 

with open('GFG', 'a') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
#     write.writerow(fields)
    write.writerows(log)
